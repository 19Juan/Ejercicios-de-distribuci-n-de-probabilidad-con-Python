# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO
from scipy.stats import norm

#Definir funciones de probabilidad para la distribución normal.

def dnorm(x, mean = 0, desvest = 1):
    
#Calcula la estimación puntual de la distribución normal.
    result = norm.pdf(x, loc = mean, scale = desvest)

    return result

#Calcula el acumulado de la distribución normal.
def pnorm(q, mean = 0, desvest = 1):

    result= norm.cdf(q, loc = mean, scale = desvest)

    return result
#Calcula la función cuantil a partir de la distribución normal.
def qnorm(p, mean = 0, desvest = 1):

    result = norm.ppf(p, loc = mean, scale = desvest)

    return result
#Genera variables aleatorias a partir de la distribución normal.
def rnorm(n, mean = 0, desvest = 1):

    result = norm.rvs(size = n, loc = mean, scale = desvest)

    return result

from scipy.stats import uniform

#Definir funciones de probabilidad para la distribución uniforme.

def dunif(x, minimo = 0, maximo = 1):
    #Calcula la estimación puntual de la distribución uniforme.
    result = uniform.pdf(x, loc = minimo, scale = maximo - minimo)
    
    return result

#Calcula el acumulado de la distribución uniforme.
def punif(q, minimo = 0, maximo = 1):
    result = uniform.cdf(q, loc = minimo, scale = maximo - minimo)
    
    return result

#Calcula la función cuantil a partir de la distribución uniforme.
def qunif(p, minimo = 0, maximo = 1):
    result = uniform.ppf(p, loc = minimo, scale = maximo - minimo)
    
    return result

#Genera variables aleatorias a partir de la distribución uniforme.
def runif(n, minimo = 0, maximo = 1):
    result = uniform.rvs(size = n, loc = minimo, scale = maximo - minimo)
    
    return result




#Gráficos de las distribuciones
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(40)

data = rnorm(1000, mean = 1, desvest = 2)

pdf = dnorm(data, mean = 1, desvest = 2)
cdf = pnorm(data, mean = 1, desvest = 2)
ppf = qnorm(data, mean = 1, desvest = 2)

fig, axis = plt.subplots(3,1 , figsize = (6, 9))

axis[0].stem(data, pdf, "y-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()


#uniforme

low=0
High=1
data_uniform = runif(1000, minimo=low, maximo=High)

pdf_unif = dunif(data,minimo=low, maximo=High)
cdf_unif = punif(data,minimo=low, maximo=High)
ppf_unif = qunif(data,minimo=low, maximo=High)

fig, axis = plt.subplots(3,1 , figsize = (6,9))

axis[0].stem(data_uniform, pdf_unif, "y-")
axis[1].stem(data_uniform, cdf_unif, "b-")
axis[2].stem(data_uniform, ppf_unif, "r-")

plt.show()
